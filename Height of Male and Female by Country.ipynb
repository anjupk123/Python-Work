# %%
#Import library 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#data importing

HGC=pd.read_excel('Height of Male and Female by Country.xlsx')

HGC
# Out:
#       Rank            Country Name  Male Height in Cm  Female Height in Cm  \
# 0      1.0             Netherlands             183.78               170.36
# 1      2.0              Montenegro             183.30               169.96
# 2      3.0                 Estonia             182.79               168.66
# 3      4.0  Bosnia and Herzegovina             182.47               167.47
# 4      5.0                 Iceland             182.10               168.91
# ..     ...                     ...                ...                  ...
# 194  195.0              Mozambique             164.30               155.42
# 195  196.0        Papua New Guinea             163.10               156.89
# 196  197.0         Solomon Islands             163.07               156.79
# 197  198.0                    Laos             162.78               153.10
# 198  199.0             Timor-Leste             160.13               152.71
#
#      Male Height in Ft  Female Height in Ft
# ...

# %%
# head() will show 1 st 5 rows of the data
HGC.head()
# Out:
#    Rank            Country Name  Male Height in Cm  Female Height in Cm  \
# 0   1.0             Netherlands             183.78               170.36
# 1   2.0              Montenegro             183.30               169.96
# 2   3.0                 Estonia             182.79               168.66
# 3   4.0  Bosnia and Herzegovina             182.47               167.47
# 4   5.0                 Iceland             182.10               168.91
#
#    Male Height in Ft  Female Height in Ft
# 0               6.03                 5.59
# 1               6.01                 5.58
# 2               6.00                 5.53
# 3               5.99                 5.49
# 4               5.97                 5.54

# %%
#Tail() show the last 5 rows
HGC.tail()
# Out:
#       Rank      Country Name  Male Height in Cm  Female Height in Cm  \
# 194  195.0        Mozambique             164.30               155.42
# 195  196.0  Papua New Guinea             163.10               156.89
# 196  197.0   Solomon Islands             163.07               156.79
# 197  198.0              Laos             162.78               153.10
# 198  199.0       Timor-Leste             160.13               152.71
#
#      Male Height in Ft  Female Height in Ft
# 194               5.39                 5.10
# 195               5.35                 5.15
# 196               5.35                 5.14
# 197               5.34                 5.02
# 198               5.25                 5.01

# %%
#199 rows and 6 columns
HGC.shape
# Out:
# (199, 6)

# %%
HGC.describe()
# Out:
#              Rank  Male Height in Cm  Female Height in Cm  Male Height in Ft  \
# count  199.000000         199.000000           199.000000         199.000000
# mean   100.000000         173.089045           160.942915           5.678794
# std     57.590508           4.949832             4.076377           0.162510
# min      1.000000         160.130000           150.910000           5.250000
# 25%     50.500000         169.490000           158.240000           5.560000
# 50%    100.000000         173.530000           160.620000           5.690000
# 75%    149.500000         176.510000           163.870000           5.790000
# max    199.000000         183.780000           170.360000           6.030000
#
#        Female Height in Ft
# count           199.000000
# mean              5.280402
# std               0.133870
# min               4.950000
# 25%               5.190000
# 50%               5.270000
# 75%               5.375000
# max               5.590000

# %%
#shows the column names
HGC.columns
# Out:
# Index(['Rank', 'Country Name', 'Male Height in Cm', 'Female Height in Cm',
#        'Male Height in Ft', 'Female Height in Ft'],
#       dtype='object')

# %%
#Total number of missing rows
HGC.isnull().sum()
# Out:
# Rank                   0
# Country Name           0
# Male Height in Cm      0
# Female Height in Cm    0
# Male Height in Ft      0
# Female Height in Ft    0
# dtype: int64

# %% [markdown]
# ### There are no duplicates in the data.

# %%
#Check if there are any duplicates
HGC.duplicated().any()
# Out:
# False

# %%
#checking null values
HGC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 199 non-null    float64
#  1   Country Name         199 non-null    object
#  2   Male Height in Cm    199 non-null    float64
#  3   Female Height in Cm  199 non-null    float64
#  4   Male Height in Ft    199 non-null    float64
#  5   Female Height in Ft  199 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 9.5+ KB

# %% [markdown]
# # Data Analysis and visualiation of Height of Male and Female by Country

# %%
HGC['Country Name'].value_counts()
# Out:
# Netherlands    1
# Djibouti       1
# Zimbabwe       1
# Mongolia       1
# El Salvador    1
#               ..
# Palestine      1
# Algeria        1
# Mali           1
# Kuwait         1
# Timor-Leste    1
# Name: Country Name, Length: 199, dtype: int64

# %% [markdown]
# ### There are unique() method

# %%
# The list of countries 
HGC['Country Name'].unique()
# Out:
# array(['Netherlands', 'Montenegro', 'Estonia', 'Bosnia and Herzegovina',
#        'Iceland', 'Denmark', 'Czech Republic', 'Latvia', 'Slovakia',
#        'Slovenia', 'Ukraine', 'Croatia', 'Serbia', 'Lithuania', 'Poland',
#        'Finland', 'Norway', 'Sweden', 'Germany', 'Dominica', 'Bermuda',
#        'Puerto Rico', 'Greece', 'Belgium', 'Ireland', 'Lebanon',
#        'Andorra', 'Antigua and Barbuda', 'Australia', 'Canada',
#        'Switzerland', 'Grenada', 'Belarus', 'France', 'Austria',
#        'Luxembourg', 'Cook Islands', 'French Polynesia', 'United Kingdom',
#        'Romania', 'New Zealand', 'Saint Vincent and the Grenadines',
#        'Niue', 'American Samoa', 'Barbados', 'Jamaica', 'United States',
#        'Tunisia', 'Russia', 'Hungary', 'Saint Lucia', 'North Macedonia',
#        'Libya', 'Turkey', 'Morocco', 'Senegal', 'Spain', 'Tokelau',
#        'Trinidad and Tobago', 'Israel', 'Georgia', 'Seychelles', 'Brazil',
# ...

# %%
#correlation
HGC.corr()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#                          Rank  Male Height in Cm  Female Height in Cm  \
# Rank                 1.000000          -0.992041            -0.924239
# Male Height in Cm   -0.992041           1.000000             0.928787
# Female Height in Cm -0.924239           0.928787             1.000000
# Male Height in Ft   -0.991887           0.999854             0.928406
# Female Height in Ft -0.923155           0.927642             0.999792
#
#                      Male Height in Ft  Female Height in Ft
# Rank                         -0.991887            -0.923155
# Male Height in Cm             0.999854             0.927642
# Female Height in Cm           0.928406             0.999792
# Male Height in Ft             1.000000             0.927259
# ...

# %%
# Find sum of Male Height in Cm 
HGC['Male Height in Cm'].sum()
# Out:
# 34444.72

# %%
# Find sum of Female Height in Cm 
HGC['Female Height in Cm'].sum()
# Out:
# 32027.64

# %%
# Find sum of Male Height in Ft
HGC['Male Height in Ft'].sum()
# Out:
# 1130.08

# %%
# Find sum of Female Height in Ft
HGC['Female Height in Ft'].sum()
# Out:
# 1050.8

# %%
# Find India
HGC[HGC['Country Name']== 'India']
# Out:
#       Rank Country Name  Male Height in Cm  Female Height in Cm  \
# 178  179.0        India              166.5               155.18
#
#      Male Height in Ft  Female Height in Ft
# 178               5.46                 5.09

# %%
# Find Greece
HGC[HGC['Country Name']== 'Greece']
# Out:
#     Rank Country Name  Male Height in Cm  Female Height in Cm  \
# 22  23.0       Greece             179.26               165.81
#
#     Male Height in Ft  Female Height in Ft
# 22               5.88                 5.44

# %%
# This is show kdeplotsns Male Height in Cm
sns.kdeplot(HGC['Male Height in Cm'])
# Out:
# <AxesSubplot:xlabel='Male Height in Cm', ylabel='Density'>

# %%
# This is show kdeplotsns Female Height in Cm
sns.kdeplot(HGC['Female Height in Cm'])
# Out:
# <AxesSubplot:xlabel='Female Height in Cm', ylabel='Density'>

# %%
# This is show kdeplotsns Male Height in Ft
sns.kdeplot(HGC['Male Height in Ft'])
# Out:
# <AxesSubplot:xlabel='Male Height in Ft', ylabel='Density'>

# %%
# This is show kdeplotsns Female Height in Ft
sns.kdeplot(HGC['Female Height in Ft'])
# Out:
# <AxesSubplot:xlabel='Female Height in Ft', ylabel='Density'>

# %%
#scatterplot
sns.pairplot(HGC)

# %%
sns.scatterplot(x=HGC['Male Height in Cm'], y=HGC['Female Height in Cm'])
# Out:
# <AxesSubplot:xlabel='Male Height in Cm', ylabel='Female Height in Cm'>

# %%
sns.scatterplot(x=HGC['Male Height in Ft'], y=HGC['Female Height in Ft'])
# Out:
# <AxesSubplot:xlabel='Male Height in Ft', ylabel='Female Height in Ft'>

# %%
plt.figure(figsize=(15,12))
cor=Oorjja.corr()
sns.heatmap(cor,annot=True,cmap='cividis')
# Out:
# <AxesSubplot:>

# %%
#Histogram
HGC.hist()
plt.show()

# %%
# Histogram 
sns.histplot(HGC['Male Height in Cm'], kde=False)

# Add title
plt.title("Histogram of Male Heights")

# %%
# Histogram 
sns.histplot(HGC['Female Height in Cm'], kde=False)

# Add title
plt.title("Histogram of Female Height in Cm")

# %%
# Histogram 
sns.histplot(HGC['Male Height in Ft'], kde=False)

# Add title
plt.title("Histogram of Male Height in Ft")

# %%
# Histogram 
sns.histplot(HGC['Female Height in Ft'], kde=False)

# Add title
plt.title("Histogram of Female Height in Ft")

# %% [markdown]
# ## Conclusion
#
# This is the name of data in Height of Males and Female by Country
#
# There are 199 rows and 6 columns of data
#
# The number of the country names of HGC data.
#
# The country name of unique to the columns.
#
# The histogram is the most female Height Ft is 5.2 and the female Height Ft is 5.0.
#
# It is show correlation.
#
# It is find show india.
#
# It shows kdeplot.
#
# It shows scatterplot
